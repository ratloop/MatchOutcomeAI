# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import LabelEncoder

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
def get_recent_form(data, team, n_matches=5):
    team_data = data[(data['home_team'] == team) | (data['away_team'] == team)].tail(n_matches)
    wins = 0
    draws = 0
    losses = 0
    for _, row in team_data.iterrows():
        if row['result'] == 1 and row['home_team'] == team:
            wins += 1
        elif row['result'] == -1 and row['away_team'] == team:
            wins += 1
        elif row['result'] == 0:
            draws += 1
        else:
            losses += 1

    return wins / n_matches, draws / n_matches, losses / n_matches

# %%
data = pd.read_csv("../data/csv_datasets/epl/all_seasons.csv")

# %%
le_home = LabelEncoder()
le_away = LabelEncoder()

# %%
data['home_team'] = le_home.fit_transform(data['home_team'])
data.head()
# Out:
#    fixture_id  season                       date             stadium  \
# 0       17317    2016  2017-05-21T14:00:00+00:00    Emirates Stadium
# 1       17318    2016  2017-05-21T14:00:00+00:00           Turf Moor
# 2       17319    2016  2017-05-21T14:00:00+00:00     Stamford Bridge
# 3       17320    2016  2017-05-21T14:00:00+00:00        KCOM Stadium
# 4       17321    2016  2017-05-21T14:00:00+00:00  King Power Stadium
#
#              game_week  home_team    away_team  home_goals  away_goals  \
# 0  Regular Season - 38          0      Everton           3           1
# 1  Regular Season - 38          5     West Ham           1           2
# 2  Regular Season - 38          7   Sunderland           5           1
# 3  Regular Season - 38         12    Tottenham           1           7
# 4  Regular Season - 38         14  Bournemouth           1           1
#
#    ht_home_goals  ...  away_shots  away_fouls  away_corners  away_offsides  \
# 0              2  ...          22          15             6              1
# 1              1  ...          14          14             5              3
# 2              1  ...           7          15             1              1
# 3              0  ...          19           5             3              0
# 4              0  ...          10          10             1              1
#
#    away_possession  away_yellow_cards  away_red_cards  away_goalkeeper_saves  \
# 0               51                  4               0                      6
# 1               56                  2               0                      0
# 2               30                  1               0                      3
# 3               66                  0               0                      3
# 4               52                  1               0                      4
#
#    away_attempted_passes  away_successful_passes
# 0                    428                     366
# 1                    489                     374
# 2                    269                     211
# 3                    600                     520
# 4                    446                     350
#
# [5 rows x 33 columns]

# %%
data['away_team'] = le_away.fit_transform(data['away_team'])
data.head()
# Out:
#    fixture_id  season                       date             stadium  \
# 0       17317    2016  2017-05-21T14:00:00+00:00    Emirates Stadium
# 1       17318    2016  2017-05-21T14:00:00+00:00           Turf Moor
# 2       17319    2016  2017-05-21T14:00:00+00:00     Stamford Bridge
# 3       17320    2016  2017-05-21T14:00:00+00:00        KCOM Stadium
# 4       17321    2016  2017-05-21T14:00:00+00:00  King Power Stadium
#
#              game_week  home_team  away_team  home_goals  away_goals  \
# 0  Regular Season - 38          0          9           3           1
# 1  Regular Season - 38          5         30           1           2
# 2  Regular Season - 38          7         25           5           1
# 3  Regular Season - 38         12         27           1           7
# 4  Regular Season - 38         14          2           1           1
#
#    ht_home_goals  ...  away_shots  away_fouls  away_corners  away_offsides  \
# 0              2  ...          22          15             6              1
# 1              1  ...          14          14             5              3
# 2              1  ...           7          15             1              1
# 3              0  ...          19           5             3              0
# 4              0  ...          10          10             1              1
#
#    away_possession  away_yellow_cards  away_red_cards  away_goalkeeper_saves  \
# 0               51                  4               0                      6
# 1               56                  2               0                      0
# 2               30                  1               0                      3
# 3               66                  0               0                      3
# 4               52                  1               0                      4
#
#    away_attempted_passes  away_successful_passes
# 0                    428                     366
# 1                    489                     374
# 2                    269                     211
# 3                    600                     520
# 4                    446                     350
#
# [5 rows x 33 columns]

# %%
data['game_week'] = data['game_week'].str.extract('(\d+)').astype(int)
data.head()
# Out:
#    fixture_id  season                       date             stadium  \
# 0       17317    2016  2017-05-21T14:00:00+00:00    Emirates Stadium
# 1       17318    2016  2017-05-21T14:00:00+00:00           Turf Moor
# 2       17319    2016  2017-05-21T14:00:00+00:00     Stamford Bridge
# 3       17320    2016  2017-05-21T14:00:00+00:00        KCOM Stadium
# 4       17321    2016  2017-05-21T14:00:00+00:00  King Power Stadium
#
#    game_week  home_team  away_team  home_goals  away_goals  ht_home_goals  \
# 0         38          0          9           3           1              2
# 1         38          5         30           1           2              1
# 2         38          7         25           5           1              1
# 3         38         12         27           1           7              0
# 4         38         14          2           1           1              0
#
#    ...  away_shots  away_fouls  away_corners  away_offsides  away_possession  \
# 0  ...          22          15             6              1               51
# 1  ...          14          14             5              3               56
# 2  ...           7          15             1              1               30
# 3  ...          19           5             3              0               66
# 4  ...          10          10             1              1               52
#
#    away_yellow_cards  away_red_cards  away_goalkeeper_saves  \
# 0                  4               0                      6
# 1                  2               0                      0
# 2                  1               0                      3
# 3                  0               0                      3
# 4                  1               0                      4
#
#    away_attempted_passes  away_successful_passes
# 0                    428                     366
# 1                    489                     374
# 2                    269                     211
# 3                    600                     520
# 4                    446                     350
#
# [5 rows x 33 columns]

# %%
data['result'] = np.sign(data['home_goals'] - data['away_goals'])
data.head()
# Out:
#    fixture_id  season                       date             stadium  \
# 0       17317    2016  2017-05-21T14:00:00+00:00    Emirates Stadium
# 1       17318    2016  2017-05-21T14:00:00+00:00           Turf Moor
# 2       17319    2016  2017-05-21T14:00:00+00:00     Stamford Bridge
# 3       17320    2016  2017-05-21T14:00:00+00:00        KCOM Stadium
# 4       17321    2016  2017-05-21T14:00:00+00:00  King Power Stadium
#
#    game_week  home_team  away_team  home_goals  away_goals  ht_home_goals  \
# 0         38          0          9           3           1              2
# 1         38          5         30           1           2              1
# 2         38          7         25           5           1              1
# 3         38         12         27           1           7              0
# 4         38         14          2           1           1              0
#
#    ...  away_fouls  away_corners  away_offsides  away_possession  \
# 0  ...          15             6              1               51
# 1  ...          14             5              3               56
# 2  ...          15             1              1               30
# 3  ...           5             3              0               66
# 4  ...          10             1              1               52
#
#    away_yellow_cards  away_red_cards  away_goalkeeper_saves  \
# 0                  4               0                      6
# 1                  2               0                      0
# 2                  1               0                      3
# 3                  0               0                      3
# 4                  1               0                      4
#
#    away_attempted_passes  away_successful_passes  result
# 0                    428                     366       1
# 1                    489                     374      -1
# 2                    269                     211       1
# 3                    600                     520      -1
# 4                    446                     350       0
#
# [5 rows x 34 columns]

# %%
scaling_factor = 2

data['home_recent_wins'] = data['home_team'].apply(lambda x: get_recent_form(data, x)[0]) * scaling_factor
data['home_recent_draws'] = data['home_team'].apply(lambda x: get_recent_form(data, x)[1]) * scaling_factor
data['home_recent_losses'] = data['home_team'].apply(lambda x: get_recent_form(data, x)[2]) * scaling_factor
data['away_recent_wins'] = data['away_team'].apply(lambda x: get_recent_form(data, x)[0]) * scaling_factor
data['away_recent_draws'] = data['away_team'].apply(lambda x: get_recent_form(data, x)[1]) * scaling_factor
data['away_recent_losses'] = data['away_team'].apply(lambda x: get_recent_form(data, x)[2]) * scaling_factor
data.head()
# Out:
#    fixture_id  season                       date             stadium  \
# 0       17317    2016  2017-05-21T14:00:00+00:00    Emirates Stadium
# 1       17318    2016  2017-05-21T14:00:00+00:00           Turf Moor
# 2       17319    2016  2017-05-21T14:00:00+00:00     Stamford Bridge
# 3       17320    2016  2017-05-21T14:00:00+00:00        KCOM Stadium
# 4       17321    2016  2017-05-21T14:00:00+00:00  King Power Stadium
#
#    game_week  home_team  away_team  home_goals  away_goals  ht_home_goals  \
# 0         38          0          9           3           1              2
# 1         38          5         30           1           2              1
# 2         38          7         25           5           1              1
# 3         38         12         27           1           7              0
# 4         38         14          2           1           1              0
#
#    ...  away_goalkeeper_saves  away_attempted_passes  away_successful_passes  \
# 0  ...                      6                    428                     366
# 1  ...                      0                    489                     374
# 2  ...                      3                    269                     211
# 3  ...                      3                    600                     520
# 4  ...                      4                    446                     350
#
#    result  home_recent_wins  home_recent_draws  home_recent_losses  \
# 0       1               0.8                1.2                 0.0
# 1      -1               0.8                0.0                 1.2
# 2       1               0.4                0.4                 1.2
# 3      -1               0.8                0.4                 0.8
# 4       0               0.4                0.4                 1.2
#
#    away_recent_wins  away_recent_draws  away_recent_losses
# 0               0.0                1.2                 0.8
# 1               1.2                0.8                 0.0
# 2               0.0                0.4                 1.6
# 3               0.4                0.8                 0.8
# 4               1.2                0.0                 0.8
#
# [5 rows x 40 columns]

# %%
features = [
    'game_week',
    'home_team',
    'away_team',
    'home_shots_on_target',
    'home_shots',
    'home_fouls',
    'home_corners',
    'home_offsides',
    'home_possession',
    'home_yellow_cards',
    'home_red_cards',
    'home_goalkeeper_saves',
    'home_attempted_passes',
    'home_successful_passes',
    'away_shots_on_target',
    'away_shots',
    'away_fouls',
    'away_corners',
    'away_offsides',
    'away_possession',
    'away_yellow_cards',
    'away_red_cards',
    'away_goalkeeper_saves',
    'away_attempted_passes',
    'away_successful_passes',
    'home_recent_wins',
    'home_recent_draws',
    'home_recent_losses',
    'away_recent_wins',
    'away_recent_draws',
    'away_recent_losses'
]

ml_features = data[features]

ml_features
# Out:
#       game_week  home_team  away_team  home_shots_on_target  home_shots  \
# 0            38          0          9                     9          17
# 1            38          5         30                     1           9
# 2            38          7         25                     8          28
# 3            38         12         27                     4          10
# 4            38         14          2                     4          20
# ...         ...        ...        ...                   ...         ...
# 2592         32         15         21                     6          18
# 2593         32         19         27                     8          25
# 2594         33         13         14                     3          13
# 2595         33         31          8                     3           9
# 2596         33          1         10                     3          14
#
#       home_fouls  home_corners  home_offsides  home_possession  \
# 0             10             4              0               49
# 1             11             2              0               44
# 2              8            11              0               70
# 3             14             2              2               34
# 4             11             9              5               48
# ...          ...           ...            ...              ...
# 2592           9             9              2               81
# 2593           7             9              2               57
# 2594          14             3              4               41
# 2595          13             6              2               41
# 2596           6             8              0               52
#
#       home_yellow_cards  ...  away_red_cards  away_goalkeeper_saves  \
# 0                     2  ...               0                      6
# 1                     2  ...               0                      0
# 2                     1  ...               0                      3
# 3                     0  ...               0                      3
# 4                     4  ...               0                      4
# ...                 ...  ...             ...                    ...
# 2592                  0  ...               0                      2
# 2593                  0  ...               0                      2
# 2594                  4  ...               0                      2
# 2595                  5  ...               0                      2
# 2596                  3  ...               0                      2
#
#       away_attempted_passes  away_successful_passes  home_recent_wins  \
# 0                       428                     366               0.8
# 1                       489                     374               0.8
# 2                       269                     211               0.4
# 3                       600                     520               0.8
# 4                       446                     350               0.4
# ...                     ...                     ...               ...
# 2592                    148                      78               0.8
# 2593                    401                     317               1.6
# 2594                    444                     324               0.0
# 2595                    434                     357               1.2
# 2596                    399                     324               1.6
#
#       home_recent_draws  home_recent_losses  away_recent_wins  \
# 0                   1.2                 0.0               0.0
# 1                   0.0                 1.2               1.2
# 2                   0.4                 1.2               0.0
# 3                   0.4                 0.8               0.4
# 4                   0.4                 1.2               1.2
# ...                 ...                 ...               ...
# 2592                0.4                 0.8               0.0
# 2593                0.0                 0.4               0.4
# 2594                0.4                 1.6               0.4
# 2595                0.4                 0.4               1.2
# 2596                0.4                 0.0               0.8
#
#       away_recent_draws  away_recent_losses
# 0                   1.2                 0.8
# 1                   0.8                 0.0
# 2                   0.4                 1.6
# 3                   0.8                 0.8
# 4                   0.0                 0.8
# ...                 ...                 ...
# 2592                0.4                 1.6
# 2593                0.8                 0.8
# 2594                0.4                 1.2
# 2595                0.4                 0.4
# 2596                0.0                 1.2
#
# [2597 rows x 31 columns]

# %%
ml_target = data['result']

ml_target
# Out:
# 0       1
# 1      -1
# 2       1
# 3      -1
# 4       0
#        ..
# 2592    1
# 2593    1
# 2594    0
# 2595    1
# 2596    1
# Name: result, Length: 2597, dtype: int64

# %%
ml_features_train, ml_features_test, ml_target_train, ml_target_test = train_test_split(ml_features, ml_target, test_size=0.2, random_state=42)

clf = SVC(probability=True)
clf.fit(ml_features_train, ml_target_train)

model_test = clf.predict(ml_features_test)

# %%
cv_scores = cross_val_score(clf, ml_features, ml_target, cv=5)

print(f"Cross-validation scores: {cv_scores}")
print(f"Mean cross-validation score: {cv_scores.mean():.4f}")
# Out:
# Cross-validation scores: [0.48076923 0.50769231 0.48362235 0.48169557 0.4894027 ]
# Mean cross-validation score: 0.4886

# %%
accuracy = accuracy_score(ml_target_test, model_test)
precision = precision_score(ml_target_test, model_test, average='weighted')
recall = recall_score(ml_target_test, model_test, average='weighted')
f1 = f1_score(ml_target_test, model_test, average='weighted')

print(f"Accuracy: {accuracy * 100:.2f}%")
print(f"Precision: {precision * 100:.2f}%")
print(f"Recall: {recall * 100:.2f}%")
print(f"F1-score: {f1 * 100:.2f}%")
# Out:
# Accuracy: 54.42%
# Precision: 46.00%
# Recall: 54.42%
# F1-score: 44.61%

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ml_target_test, model_test)
cm_df = pd.DataFrame(cm, index=['Away Win', 'Draw', 'Home Win'], columns=['Away Win', 'Draw', 'Home Win'])
plt.figure(figsize=(5.5,4))
sns.heatmap(cm_df, annot=True, fmt='g')
plt.title('Confusion Matrix \nAccuracy: {0:.3f}'.format(accuracy_score(ml_target_test, model_test)))
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
def predict_outcome(home_team, away_team):
    home_recent_wins, home_recent_draws, home_recent_losses = get_recent_form(data, le_home.transform([home_team])[0])
    away_recent_wins, away_recent_draws, away_recent_losses = get_recent_form(data, le_away.transform([away_team])[0])
    
    input_data = np.array([
        [1, le_home.transform([home_team])[0], le_away.transform([away_team])[0]] + [0] * 22 +
        [home_recent_wins * scaling_factor, home_recent_draws * scaling_factor, home_recent_losses * scaling_factor,
        away_recent_wins * scaling_factor, away_recent_draws * scaling_factor, away_recent_losses * scaling_factor]
    ])
    prediction = clf.predict(input_data)[0]
    probabilities = clf.predict_proba(input_data)[0]
    return prediction, probabilities

# %%
fixtures = [
    ['Arsenal', 'Southampton'],
    ['Fulham', 'Leeds'],
    ['Manchester United', 'Chelsea'],
    ['Crystal Palace', 'Everton'],
    ['Liverpool', 'Nottingham Forest'],
    ['Brentford', 'Aston Villa'],
    ['Leicester', 'Wolves'],
    ['Brighton', 'Manchester City'],
    ['Newcastle', 'Tottenham'],
    ['Bournemouth', 'West Ham'],
    ]

for fixture in fixtures:
    home_team = fixture[0]
    away_team = fixture[1]
    prediction, probabilities = predict_outcome(home_team, away_team)

    print(f"{home_team} (Home) Win - {probabilities[2] * 100:.2f}%")
    print(f"{away_team} (Away) Win - {probabilities[0] * 100:.2f}%")
    print(f"Draw - {probabilities[1] * 100:.2f}%\n")
# Out:
# Arsenal (Home) Win - 24.01%
# Southampton (Away) Win - 43.86%
# Draw - 32.13%
#
# Fulham (Home) Win - 21.56%
# Leeds (Away) Win - 44.35%
# Draw - 34.08%
#
# Manchester United (Home) Win - 20.06%
# Chelsea (Away) Win - 44.76%
# Draw - 35.18%
#
# Crystal Palace (Home) Win - 21.22%
# Everton (Away) Win - 44.43%
# Draw - 34.35%
#
# Liverpool (Home) Win - 21.95%
# Nottingham Forest (Away) Win - 44.27%
# Draw - 33.78%
#
# Brentford (Home) Win - 20.85%
# Aston Villa (Away) Win - 44.52%
# Draw - 34.63%
#
# Leicester (Home) Win - 23.13%
# Wolves (Away) Win - 44.02%
# Draw - 32.85%
#
# Brighton (Home) Win - 22.55%
# Manchester City (Away) Win - 44.13%
# Draw - 33.32%
#
# Newcastle (Home) Win - 22.08%
# Tottenham (Away) Win - 44.24%
# Draw - 33.68%
#
# Bournemouth (Home) Win - 24.43%
# West Ham (Away) Win - 43.80%
# Draw - 31.77%
